# %% [markdown]
# sk-lAZTk2A_Vvc23QUWnOTb0JTjgqF-3ZgQ4nGBo25Q5yT3BlbkFJ6zXIFwDSFZD_6OAW5iWs5j_RjNE3yw4H8o2Hh0tx0A

# %%
from TxtSplitter import *
from chatbot import *
from file_process_manager import add_documents, delete_documents

# %%
'''
import torch
print(torch.cuda.is_available())        # Cela doit retourner True si CUDA est disponible
print(torch.cuda.current_device())      # Devrait afficher le numéro de votre GPU
print(torch.cuda.get_device_name(0))    # Le nom de votre GPU
'''
# Out:
# True
# 0
# NVIDIA GeForce RTX 3060 Laptop GPU

# %%
chatbot = Chatbot()
# Out:
# c:\Users\delah\Documents\GitHub\ChatBot\database_manager.py:20: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings(openai_api_key=self.api_key)
# c:\Users\delah\Documents\GitHub\ChatBot\database_manager.py:21: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   self.db = Chroma(embedding_function=embeddings, persist_directory=self.persist_directory)
# ...

# %%
from config import DATA_BASE_DIR

print(DATA_BASE_DIR)
# Out:
# c:\Users\delah\Desktop\ESILV A4\test pipeline process\data\data_base_folder

# %%
# Poser une question
response = chatbot.ask("Quelle est la liste des jours fériés ?")
#print(response["answer"]) variable à return à kentin
# Out:
# c:\Users\delah\Documents\GitHub\ChatBot\chatbot.py:90: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm = ChatOpenAI(api_key=self.key, model=MODEL, streaming=True)
# La liste des jours fériés peut varier selon le pays, mais voici une liste des jours fériés généralement observés en France :
#
# 1. **Jour de l'An** - 1er janvier
# 2. **Lundi de Pâques** - date variable
# 3. **Fête du Travail** - 1er mai
# 4. **Victoire de 1945** - 8 mai
# 5. **Ascension** - date variable
# 6. **Lundi de Pentecôte** - date variable
# 7. **Fête Nationale** - 14 juillet
# 8. **Assomption** - 15 août
# 9. **Toussaint** - 1er novembre
# 10. **Armistice de 1918** - 11 novembre
# 11. **Noël** - 25 décembre
#
# ...

# %%
response = chatbot.ask("quel est le nom de spiderman")
# Out:
# c:\Users\delah\Desktop\ESILV A4\test pipeline process\chatbot.py:80: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm = ChatOpenAI(api_key=self.key, model=MODEL, streaming=True)
# Le nom de Spider-Man, dans les bandes dessinées et les films, est Peter Parker.

# %%
docs_to_add = ["data/Documents - Tests/ttest3.pdf"]

add_documents(docs_to_add)
# Out:
# c:\Users\delah\Desktop\ESILV A4\test pipeline process\database_manager.py:20: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings(openai_api_key=self.api_key)
# c:\Users\delah\Desktop\ESILV A4\test pipeline process\database_manager.py:21: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
# ...

# %%
docs_to_add = ["data/Documents - Tests/FORMATION PAIE MAJ 09-24.pdf"]

add_documents(docs_to_add)
# Out:
# Image extraite de la page 1, index 1
# Image extraite de la page 1, index 2
# Image extraite de la page 2, index 1
# Image extraite de la page 2, index 2
# Image extraite de la page 3, index 1
# Image extraite de la page 3, index 2
# Image extraite de la page 4, index 1
# Image extraite de la page 4, index 2
# Image extraite de la page 5, index 1
# Image extraite de la page 5, index 2
# Image extraite de la page 6, index 1
# Image extraite de la page 6, index 2
# Image extraite de la page 7, index 1
# Image extraite de la page 7, index 2
# Image extraite de la page 8, index 1
# Image extraite de la page 8, index 2
# Image extraite de la page 9, index 1
# Image extraite de la page 9, index 2
# Image extraite de la page 10, index 1
# Image extraite de la page 10, index 2
# Image extraite de la page 11, index 1
# Image extraite de la page 11, index 2
# Image extraite de la page 12, index 1
# Image extraite de la page 12, index 2
# Image extraite de la page 13, index 1
# ...

# %%
docs_to_add = ["data/Documents - Tests/FORMATION PAIE MAJ 09-24.pdf"]

add_documents(docs_to_add)
# Out:
# Image extraite de la page 1, index 1
# Image extraite de la page 1, index 2
# Image extraite de la page 2, index 1
# Image extraite de la page 2, index 2
# Image extraite de la page 3, index 1
# Image extraite de la page 3, index 2
# Image extraite de la page 4, index 1
# Image extraite de la page 4, index 2
# Image extraite de la page 5, index 1
# Image extraite de la page 5, index 2
# Image extraite de la page 6, index 1
# Image extraite de la page 6, index 2
# Image extraite de la page 7, index 1
# Image extraite de la page 7, index 2
# Image extraite de la page 8, index 1
# Image extraite de la page 8, index 2
# Image extraite de la page 9, index 1
# Image extraite de la page 9, index 2
# Image extraite de la page 10, index 1
# Image extraite de la page 10, index 2
# Image extraite de la page 11, index 1
# Image extraite de la page 11, index 2
# Image extraite de la page 12, index 1
# Image extraite de la page 12, index 2
# Image extraite de la page 13, index 1
# ...

# %%
docs_to_add = ["data/Documents - Tests/ttest3.pdf"]

add_documents(docs_to_add)
# Out:
# c:\Users\delah\Desktop\ESILV A4\test pipeline process\database_manager.py:20: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings(openai_api_key=self.api_key)
# c:\Users\delah\Desktop\ESILV A4\test pipeline process\database_manager.py:21: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
# ...

# %%
docs_to_delete = ["ttest3.pdf", "FORMATION PAIE MAJ 09-24.pdf", "FORMATION SOCIALE MAJ 09-24.pdf"]

delete_documents(docs_to_delete)
# Out:
# Aucun document trouvé avec la source 'ttest3.pdf'
# Aucun document trouvé avec la source 'FORMATION PAIE MAJ 09-24.pdf'
# Aucun document trouvé avec la source 'FORMATION SOCIALE MAJ 09-24.pdf'

# %%
response = chatbot.ask("que prévoit la CCSS pour la paternité ?")
#print(response["answer"]) variable à return à kentin
# Out:
# La CCSS prévoit pour la paternité les dispositions suivantes :
#
# 1. **Autorisation d'absence de 2 jours** : À l'occasion de la naissance de son enfant, le père bénéficie d'une autorisation d'absence de 2 jours rémunérée par l'employeur, comme prévu par l'Avenant 18. Le salaire est maintenu en totalité par l'employeur, et ces jours d'absence n'ont aucun impact social, se matérialisant uniquement par un commentaire sur le bulletin de salaire.
#
# 2. **Congé paternité** : Selon la loi 1309 du 29/05/2006, le père peut bénéficier d'un congé paternité. La CCSS verse une indemnité journalière de paternité égale à 90% du salaire brut journalier moyen acquis par le père au cours des douze mois précédant le début du congé. Le salaire journalier moyen est calculé dans les mêmes conditions qu'en matière d'assurance maladie et d'assurance maternité.
#
# ...

# %%
response = chatbot.ask("donne moi la liste des jours feriés")
#print(response["answer"]) variable à return à kentin
# Out:
# Selon la loi 798 du 18/02/1966, la liste des jours fériés légaux est la suivante :
#
# 1. Jour de l’an
# 2. 1er mai
# 3. Assomption
# 4. Toussaint
# 5. Fête du Prince
# 6. Noël
#
# De plus, si l'Immaculée Conception tombe un dimanche, elle est reportée au lundi 9 décembre. Quand ces jours fériés tombent un dimanche, le lundi qui suit est considéré comme un jour férié légal.

# %%
response = chatbot.ask("fête du travail")
print(response["answer"])
# Out:
# La Fête du Travail, célébrée le 1er mai, est l'un des jours fériés légaux selon la loi 798 du 18/02/1966. Ce jour est traditionnellement associé à la célébration des travailleurs et des réalisations du mouvement ouvrier. La loi stipule que si ce jour tombe un dimanche, le lundi suivant est considéré comme un jour férié légal. De plus, si un salarié est amené à travailler ce jour-là, il a droit à une majoration de salaire ou à un repos compensateur, comme défini par la réglementation en vigueur.La Fête du Travail, célébrée le 1er mai, est l'un des jours fériés légaux selon la loi 798 du 18/02/1966. Ce jour est traditionnellement associé à la célébration des travailleurs et des réalisations du mouvement ouvrier. La loi stipule que si ce jour tombe un dimanche, le lundi suivant est considéré comme un jour férié légal. De plus, si un salarié est amené à travailler ce jour-là, il a droit à une majoration de salaire ou à un repos compensateur, comme défini par la réglementation en vigueur.
# ...
